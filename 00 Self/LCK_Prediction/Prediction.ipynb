# %%
import pandas as pd

# %%
data_summer = pd.read_csv('./Data/LCK_2022_Summer.csv')

# %%
data_summer
# Out:
#        경기 분류    날짜  팀 1  팀 2  팀 1 예상치  팀 2 예상치  승리 예측이 높은 팀  예측 차  팀 1 승리 세트  \
# 0    정규시즌 1R  6/15  KDF  HLE     91.0        9            1    82        2.0
# 1    정규시즌 1R  6/15   NS  DRX     28.0       72            2    44        0.0
# 2    정규시즌 1R  6/16   KT  GEN      5.0       95            2    90        0.0
# 3    정규시즌 1R  6/16  BRO   DK      4.0       96            2    92        0.0
# 4    정규시즌 1R  6/17  LSB  KDF     14.0       86            2    72        2.0
# ..       ...   ...  ...  ...      ...      ...          ...   ...        ...
# 90  플레이오프 1R  8/17  NaN  NaN      NaN      100            2   100        NaN
# 91  플레이오프 1R  8/18  NaN  NaN      NaN      100            2   100        NaN
# 92  플레이오프 2R  8/20  NaN  NaN      NaN      100            2   100        NaN
# 93  플레이오프 2R  8/21  NaN  NaN      NaN      100            2   100        NaN
# 94       결승전  8/28  NaN  NaN      NaN      100            2   100        NaN
#
#     팀 2 승리 세트  승리팀  승점  예측 성공 여부
# ...
